# %% [markdown]
# <a href="https://colab.research.google.com/github/oliviergentil/MAR_Explorer/blob/main/MAR_Explorer_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import mar_explorer as mar
import pandas as pd
import matplotlib.pyplot as plt

# %%
mar.load_years([2021, 2022, 2023, 2024, 2025],4)
# Out:
# ✓ MAR 2021, Chapter 4 loaded.
# ✓ MAR 2022, Chapter 4 loaded.
# ✓ MAR 2023, Chapter 4 loaded.
# ✓ MAR 2024, Chapter 4 loaded.
# ✓ MAR 2025, Chapter 4 already in memory.

# %%
mar.list_tables(2025,4)
# Out:
# 0 — Chart 1: EI service requests via different in-person service channels in 2024-25 *
# 1 — Image 1: EI Call Centre call volumes
# 2 — Image 2: Applications submitted using AppliWeb
# 3 — Chart 2: Preferred methods for completing EI reports
# 4 — Image 3: Documents accepted for electronic submission
# 5 — Chart 3: Applications received and claims processed
# 6 — Chart 4: Number of processing officers and EI experience
# 7 — Chart 5: Error rates (Claimant, Employer, Service Canada)
# 8 — Chart 6: Total net savings identified ($M) due to integrity activities
# 9 — Chart 7: 2024-25 EI issues most frequently requested for reconsideration
# 10 — Chart 8: Percentage of initial decisions reversed or changed following reconsideration
# 11 — Image 4: SST divisions
# 12 — Chart 9: 2024-25 adherence to the 45-day service standard for decisions following an appeal at the General Division, EI section (excluding groups)
# ...

# %%
mar.search("Applications received")
# Out:
# MAR 2025, Chapter 4
# 5 — Chart 3: Applications received and claims processed
#
# MAR 2024, Chapter 4
# 5 — Chart 3 – Applications received and claims processed

# %%
ei_reports_2025 = mar.show_table(2025, 4, 5)
# Out:
# 5 — Chart 3: Applications received and claims processed
#                                        Fiscal year  2020-21  2021-22  2022-23  \
# 0        Percentage of EI reports completed online     90.7     86.6     84.7
# 1  Percentage of EI reports completed on the phone      9.3     13.4     15.3
#
#    2023-24  2024-25
# 0     85.9     86.8
# 1     14.1     13.2

# %%
ei_reports_2024 = mar.show_table(2024, 4, 5)
# Out:
# 5 — Chart 3 – Applications received and claims processed
#                                        Fiscal year  2019-20  2020-21  2021-22  \
# 0        Percentage of EI reports completed online     80.9     90.7     86.6
# 1  Percentage of EI reports completed on the phone     19.1      9.3     13.4
#
#    2022-23  2023-24
# 0     84.7     85.9
# 1     15.3     14.1

# %%
plt.figure(figsize=(10, 6))
plt.plot(app_2025_transposed.index, app_2025_transposed['Online Reports (%)'], marker='o', label='Online Reports (%)')
plt.plot(app_2025_transposed.index, app_2025_transposed['Phone Reports (%)'], marker='o', label='Phone Reports (%)')

plt.title('Percentage of EI Reports Completed Online vs. Phone (2020-2024)')
plt.xlabel('Fiscal Year')
plt.ylabel('Percentage (%)')
plt.xticks(app_2025_transposed.index) # Ensure all fiscal years are shown on the x-axis
plt.grid(True)
plt.legend()
plt.show()
